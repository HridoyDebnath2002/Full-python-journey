# %% [markdown]
# Basic Python

# %%
print("Playon24")
# Out:
# Playon24

# %%
print("This is new line,\n please work")
# Out:
# This is new line,
#  please work

# %%
print("This is Testing")
# Out:
# This is Testing
