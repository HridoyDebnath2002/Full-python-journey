# %%
print("Hello, World!")
print("My name is Hridoy")

# %%
print("Hello, World!")
print("My name is Hridoy")

# %%
name = "Hridoy"
age = 22
height = 5.9

print(name)
print(age)
print(height)

# %%
a = 20              # int
b = 3.5             # float
c = "Python"        # string
d = True            # boolean
e = [1, 2, 3]       # list
f = (10, 20, 30)    # tuple
g = {"name": "Hridoy", "age": 22}  # dictionary
